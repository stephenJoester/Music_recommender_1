# %% [markdown]
# # Setup

# %%
# !pip install gdown
# !gdown 1AGybRCQ1OGp78whNoHhg0_R47gOoQ3md # track_metadata.csv
# !gdown 1-FHOZM7QaT0ypEZaiRKNCZAszD18oHZB # spectrogram_4k.zip
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0
# Downloading...
# From: https://drive.google.com/uc?id=1AGybRCQ1OGp78whNoHhg0_R47gOoQ3md
# To: /kaggle/working/tracks_metadata.csv
# 100%|███████████████████████████████████████| 3.79M/3.79M [00:00<00:00, 187MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1-FHOZM7QaT0ypEZaiRKNCZAszD18oHZB
# From (redirected): https://drive.google.com/uc?id=1-FHOZM7QaT0ypEZaiRKNCZAszD18oHZB&confirm=t&uuid=e9f145ab-8969-47ad-af2c-8e2c96c93906
# To: /kaggle/working/spectrogram_4k.zip
# 100%|████████████████████████████████████████| 114M/114M [00:03<00:00, 32.3MB/s]

# %% [markdown]
# # Prepare data

# %%
import pandas as pd

metadata = pd.read_csv('/kaggle/working/tracks_metadata.csv')
metadata
# Out:
#                                     track_title  \
# 0                         ...Baby One More Time
# 1     DJ Got Us Fallin' In Love (feat. Pitbull)
# 2                                        People
# 3                  Somebody That I Used To Know
# 4                      Murder On The Dancefloor
# ...                                         ...
# 3226                       That Feeling, Though
# 3227                        Everything, Forever
# 3228                                         Es
# 3229                                    Tuesday
# 3230                           Feathered Friend
#
#                                               track_url  \
# 0     https://open.spotify.com/track/3MjUtNVVq3C8Fn0...
# 1     https://open.spotify.com/track/4356Typ82hUiFAy...
# 2     https://open.spotify.com/track/26b3oVLrRUaaybJ...
# 3     https://open.spotify.com/track/1qDrWA6lyx8cLEC...
# 4     https://open.spotify.com/track/4tKGFmENO69tZR9...
# ...                                                 ...
# 3226  https://open.spotify.com/track/5W7cnjrNZcv1ITM...
# 3227  https://open.spotify.com/track/0o4STUmiHirVtus...
# 3228  https://open.spotify.com/track/0MgO8jBw4PScHUQ...
# 3229  https://open.spotify.com/track/2GuchYit1FmdtXT...
# 3230  https://open.spotify.com/track/5Ac0ipN7YqSDXOi...
#
#                                          track_album      genre  \
# 0     ...Baby One More Time (Digital Deluxe Version)        Pop
# 1               Raymond v Raymond (Expanded Edition)        Pop
# 2                                             People        Pop
# 3                                     Making Mirrors        Pop
# 4                                       Read My Lips        Pop
# ...                                              ...        ...
# 3226                            That Feeling, Though  classical
# 3227                             Everything, Forever  classical
# 3228                                              Es  classical
# 3229                                         Tuesday  classical
# 3230                                       Echo Pool  classical
#
#                     track_id  \
# 0     3MjUtNVVq3C8Fn0MP3zhXa
# 1     4356Typ82hUiFAynbLYbPn
# 2     26b3oVLrRUaaybJulow9kz
# 3     1qDrWA6lyx8cLECdZE7TV7
# 4     4tKGFmENO69tZR9ahgZu48
# ...                      ...
# 3226  5W7cnjrNZcv1ITMv3xyvkV
# 3227  0o4STUmiHirVtus3Qmyh2Y
# 3228  0MgO8jBw4PScHUQbR4ZxeF
# 3229  2GuchYit1FmdtXTxl6SbUE
# 3230  5Ac0ipN7YqSDXOi3aT37kO
#
#                                             preview_mp3 duration  \
# 0     https://p.scdn.co/mp3-preview/174e01719c3b06ee...     3:31
# 1     https://p.scdn.co/mp3-preview/1619c7342806281d...     3:40
# 2     https://p.scdn.co/mp3-preview/abcbc9adf10ae490...      3:4
# 3     https://p.scdn.co/mp3-preview/36e1e9984c1a58cb...      4:4
# 4     https://p.scdn.co/mp3-preview/340bdf7b29f2725f...     3:50
# ...                                                 ...      ...
# 3226  https://p.scdn.co/mp3-preview/0dcd5bbd59b86c48...     1:31
# 3227  https://p.scdn.co/mp3-preview/d71a607ae84f0240...     1:27
# 3228  https://p.scdn.co/mp3-preview/928a9301fb537067...     2:13
# 3229  https://p.scdn.co/mp3-preview/b154624568969ec7...     3:11
# 3230  https://p.scdn.co/mp3-preview/393cfbe2fc00f3fb...      2:8
#
#               artist_name                                         artist_url  \
# 0          Britney Spears  https://open.spotify.com/artist/26dSoYclwsYLMA...
# 1                   USHER  https://open.spotify.com/artist/23zg3TcAtWQy7J...
# 2                Libianca  https://open.spotify.com/artist/7kjSuFGKhLm8b5...
# 3                   Gotye  https://open.spotify.com/artist/2AsusXITU8P25d...
# 4     Sophie Ellis-Bextor  https://open.spotify.com/artist/2cBh5lVMg222FF...
# ...                   ...                                                ...
# 3226   Fabrizio Paterlini  https://open.spotify.com/artist/0jrFMgW018F1XV...
# 3227     Leonardo Cupelli  https://open.spotify.com/artist/4aTJ4F6R23RQkM...
# 3228   Hideyuki Hashimoto  https://open.spotify.com/artist/3NMfMCA11Xo7RU...
# 3229              Annelie  https://open.spotify.com/artist/0Rm9NmU9uyvf7t...
# 3230       Kappa Mountain  https://open.spotify.com/artist/3dExis8rqyN3Os...
#
#               release_date  ...   key  loudness  mode  speechiness  \
# 0     1999-01-12T00:00:00Z  ...   0.0    -5.745   0.0       0.0307
# 1     2010-03-30T00:00:00Z  ...   7.0    -3.398   0.0       0.1090
# 2     2022-12-06T00:00:00Z  ...  10.0    -7.621   0.0       0.0678
# 3     2011-01-01T00:00:00Z  ...   0.0    -6.932   1.0       0.0371
# 4     2002-06-06T00:00:00Z  ...   1.0    -5.281   0.0       0.0299
# ...                    ...  ...   ...       ...   ...          ...
# 3226  2020-03-06T00:00:00Z  ...   7.0   -39.805   0.0       0.0396
# 3227  2020-03-19T00:00:00Z  ...   4.0   -32.354   1.0       0.0500
# 3228  2020-06-26T00:00:00Z  ...   2.0   -30.527   1.0       0.0313
# 3229  2020-04-03T00:00:00Z  ...   4.0   -30.328   0.0       0.0384
# 3230  2020-05-08T00:00:00Z  ...   9.0   -18.372   1.0       0.0501
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.20200          0.000131    0.4430   0.9070   92.960
# 1          0.03380          0.000000    0.0820   0.6540  119.963
# 2          0.55100          0.000013    0.1020   0.6930  124.357
# 3          0.54800          0.000115    0.0989   0.7480  129.059
# 4          0.00234          0.000026    0.3120   0.8870  117.310
# ...            ...               ...       ...      ...      ...
# 3226       0.99400          0.865000    0.0996   0.1470   73.490
# 3227       0.99300          0.963000    0.1010   0.0800   65.959
# 3228       0.99100          0.948000    0.1120   0.2300   71.681
# 3229       0.99000          0.902000    0.0891   0.0703  104.033
# 3230       0.99500          0.908000    0.0886   0.3430   98.181
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                5.0
# 3                4.0
# 4                4.0
# ...              ...
# 3226             1.0
# 3227             3.0
# 3228             4.0
# 3229             4.0
# 3230             3.0
#
# [3231 rows x 24 columns]

# %%
# !unzip -q spectrogram_4k.zip
# !rm spectrogram_4k.zip

# %%
import os
len(os.listdir('spectrogram'))
# Out:
# 3231

# %%
a = os.listdir('spectrogram')
print(a[:10])
# Out:
# ['jazz_7HzNXTue6la8kfSC9cXnGa.jpg', 'rock_5DtLkQnQfzJYj8QBJKYiqS.jpg', 'rock_3bnVBN67NBEzedqQuWrpP4.jpg', 'classical_6EoJEIBUGglxxadVHaebul.jpg', 'classical_7AbVRoHrQB3JMHC8J1P3Hi.jpg', 'classical_74MpGOOWWTuNzkKuo27rYe.jpg', 'country_5oHHMDcVOmPSFrCgdbHPdb.jpg', 'electronic_3I9EczoLGHQpertnkoWmZG.jpg', 'rock_0NJKX45ZZnGWyDcEnoH7C5.jpg', 'instrumental_1yGi29gqjufSYeNWY2wPca.jpg']

# %% [markdown]
# # Load data

# %%
import os
import re
import numpy as np
import cv2
# from import_data import create_spectrogram
# from slice_spectrogram import slice_spect
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tqdm import tqdm

"""
Converts images and labels into training and testing matrices.
"""
base_data_path = '/kaggle/working'
spectrogram_dir = 'spectrogram'
save_data_path = '/kaggle/working/Training_Data'
def load_dataset(verbose=1, mode=None, test_size=0.1):
    genre = {
        "pop": 0,
        "classical": 1,
        "jazz": 2,
        "hiphop": 3,
        "electronic":4,
        "rock":5,
        "country":6,
        "instrumental":7,
    }
    n_classes = len(genre)
    genre_new = {value: key for key, value in genre.items()}

    if os.path.exists(save_data_path):
        train_x = np.load(f"{save_data_path}/train_x.npy")
        train_y = np.load(f"{save_data_path}/train_y.npy")
        test_x = np.load(f"{save_data_path}/test_x.npy")
        test_y = np.load(f"{save_data_path}/test_y.npy")
        return train_x, train_y, test_x, test_y, n_classes, genre_new

    if(verbose > 0):
        print("Compiling Training and Testing Sets ...")

    filenames = []
    for f in os.listdir(os.path.join(base_data_path, spectrogram_dir)):
        if f.endswith(".jpg"):
            filenames.append(f)

    images_all = []
    labels_all = []
    for f in tqdm(filenames):
        genre_variable = f.split("_")[0]
        temp = cv2.imread(os.path.join(base_data_path, spectrogram_dir, f), cv2.IMREAD_UNCHANGED)
        if temp.shape[:2] == (128, 1280):
            images_all.append(cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY))
            labels_all.append(genre[genre_variable])

    images = np.array(images_all)
    labels = np.array(labels_all)
    labels = labels.reshape(labels.shape[0],1)
    train_x, test_x, train_y, test_y = train_test_split(images, labels, test_size=test_size, stratify=labels, random_state=42)

    # Convert the labels into one-hot vectors.
    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y, num_classes=n_classes)

    os.makedirs(save_data_path, exist_ok=True)
    np.save("Training_Data/train_x.npy", train_x)
    np.save("Training_Data/train_y.npy", train_y)
    np.save("Training_Data/test_x.npy", test_x)
    np.save("Training_Data/test_y.npy", test_y)
    return train_x, train_y, test_x, test_y, n_classes, genre_new

train_x, train_y, test_x, test_y, n_classes, genre_new = load_dataset(verbose=1, test_size=0.2)
# Out:
# 2024-06-09 14:54:45.170826: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 14:54:45.170934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 14:54:45.268829: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Compiling Training and Testing Sets ...
# 100%|██████████| 3231/3231 [00:04<00:00, 662.79it/s]

# %%
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
# Out:
# (2584, 128, 1280) (2584, 8)
# (646, 128, 1280) (646, 8)

# %%
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, class_names):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Compute the labels from the normalized confusion matrix.
    labels = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, labels[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
target_names = [
        "pop",
        "classical",
        "jazz",
        "hiphop",
        "electronic",
        "rock",
        "country",
        "instrumental"
    ]

# %% [markdown]
# # CRNN

# %% [markdown]
# ## Create model

# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
import random
from keras.models import Sequential
from keras import initializers
from keras import optimizers
from keras.utils import plot_model
from keras.layers import *
# from load_data import load_dataset
import pandas as pd

model = Sequential()
model.add(Conv2D(filters=68, kernel_size=[3,3], padding='same', kernel_initializer = initializers.he_normal(seed=1), activation="relu", input_shape=(128,1280,1)))
# Dim = (122x122x64)
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=[2,2]))
# Dim = (61x61x64)
model.add(Conv2D(filters=137, kernel_size=[3,3], padding='same', kernel_initializer = initializers.he_normal(seed=1), activation="relu"))
# Dim = (28x28x128)
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=[3,3]))
# Dim = (14x14x128)
model.add(Conv2D(filters=137, kernel_size=[3,3], padding='same', kernel_initializer = initializers.he_normal(seed=1), activation="relu"))
# Dim = (12x12x256)
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=[4,4]))
# Dim = (6x6x256)
model.add(Conv2D(filters=137, kernel_size=[3,3], padding='same', kernel_initializer = initializers.he_normal(seed=1), activation="relu"))
# Dim = (4x4x512)
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=[4,4]))
# Dim = (2x2x512)
model.add(BatchNormalization())
model.add(Reshape((13,137)))
model.add(LSTM(units=64, return_sequences=True))
# Dim = (2048)
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(LSTM(units=64))
# Dim = (1024)
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu", kernel_initializer=initializers.he_normal(seed=1)))
# Dim = (64)
model.add(Dense(32, activation="relu", kernel_initializer=initializers.he_normal(seed=1)))
# Dim = (32)
model.add(Dense(8, activation="softmax", kernel_initializer=initializers.he_normal(seed=1)))
Dim = (8)
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 1280, 68)  │           680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 1280, 68)  │           272 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 64, 640, 68)    │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 640, 137)   │        83,981 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 640, 137)   │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 21, 213, 137)   │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 213, 137)   │       169,058 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 21, 213, 137)   │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 5, 53, 137)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 5, 53, 137)     │       169,058 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 53, 137)     │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 1, 13, 137)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1, 13, 137)     │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 13, 137)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 13, 64)         │        51,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 13, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           264 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 516,737 (1.97 MB)
#  Trainable params: 515,377 (1.97 MB)
#  Non-trainable params: 1,360 (5.31 KB)

# %% [markdown]
# ## Train model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss',
                               mode='min',
                               patience=5,
                               verbose=1,
                               restore_best_weights=True,
                               start_from_epoch=10)

# compile the model
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# fit the model
history = model.fit(train_x, train_y, epochs=50, verbose=1, validation_split=0.25, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 53s 579ms/step - accuracy: 0.1924 - loss: 2.0004 - val_accuracy: 0.0728 - val_loss: 2.0994
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.3828 - loss: 1.6536 - val_accuracy: 0.1981 - val_loss: 2.0496
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.5210 - loss: 1.4030 - val_accuracy: 0.3839 - val_loss: 1.6213
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.5914 - loss: 1.2667 - val_accuracy: 0.5294 - val_loss: 1.2937
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6300 - loss: 1.1416 - val_accuracy: 0.5867 - val_loss: 1.1152
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6451 - loss: 1.0611 - val_accuracy: 0.5882 - val_loss: 1.0927
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6624 - loss: 0.9945 - val_accuracy: 0.6146 - val_loss: 1.0779
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6760 - loss: 0.9607 - val_accuracy: 0.5619 - val_loss: 1.0272
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6910 - loss: 0.8852 - val_accuracy: 0.6053 - val_loss: 1.0483
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7048 - loss: 0.8623 - val_accuracy: 0.6935 - val_loss: 0.8665
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.6990 - loss: 0.8453 - val_accuracy: 0.6563 - val_loss: 0.8997
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7169 - loss: 0.8006 - val_accuracy: 0.6517 - val_loss: 0.9273
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7093 - loss: 0.8025 - val_accuracy: 0.6579 - val_loss: 0.9127
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.7174 - loss: 0.7994 - val_accuracy: 0.7260 - val_loss: 0.7655
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7475 - loss: 0.7393 - val_accuracy: 0.6935 - val_loss: 0.8512
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7508 - loss: 0.7354 - val_accuracy: 0.6981 - val_loss: 0.8244
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7601 - loss: 0.7031 - val_accuracy: 0.6966 - val_loss: 0.9125
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7783 - loss: 0.6563 - val_accuracy: 0.7368 - val_loss: 0.7135
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7622 - loss: 0.6927 - val_accuracy: 0.7229 - val_loss: 0.7469
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7572 - loss: 0.6793 - val_accuracy: 0.6950 - val_loss: 0.8077
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7461 - loss: 0.7019 - val_accuracy: 0.6935 - val_loss: 0.8220
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7598 - loss: 0.6519 - val_accuracy: 0.7601 - val_loss: 0.6577
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7756 - loss: 0.6210 - val_accuracy: 0.7214 - val_loss: 0.7141
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7749 - loss: 0.6137 - val_accuracy: 0.6966 - val_loss: 0.8454
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.7883 - loss: 0.6039 - val_accuracy: 0.7709 - val_loss: 0.6361
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 472ms/step - accuracy: 0.7859 - loss: 0.6206 - val_accuracy: 0.7090 - val_loss: 0.8082
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7812 - loss: 0.6119 - val_accuracy: 0.7291 - val_loss: 0.7345
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 41s 471ms/step - accuracy: 0.7991 - loss: 0.5676 - val_accuracy: 0.7059 - val_loss: 0.8050
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7989 - loss: 0.5740 - val_accuracy: 0.7322 - val_loss: 0.7570
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 29s 471ms/step - accuracy: 0.7948 - loss: 0.5802 - val_accuracy: 0.6316 - val_loss: 0.9397
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 25.

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
# Out:
# (0.0, 2.17596695125103)

# %% [markdown]
# ## Evaluate model

# %%
model.evaluate(test_x, test_y)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.7493 - loss: 0.6821
# [0.6865180730819702, 0.7678018808364868]

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(test_x)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_pred, np.argmax(test_y, axis=1))
plot_confusion_matrix(cm, target_names)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(np.argmax(test_y, axis=1), y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          pop       0.47      0.49      0.48        73
#    classical       0.82      0.88      0.85       101
#         jazz       0.96      0.91      0.93        86
#       hiphop       0.80      0.68      0.74        72
#   electronic       0.68      0.81      0.74        97
#         rock       0.70      0.68      0.69        59
#      country       0.76      0.55      0.64        51
# instrumental       0.90      0.91      0.90       107
#
#     accuracy                           0.77       646
#    macro avg       0.76      0.74      0.75       646
# weighted avg       0.77      0.77      0.77       646

# %%
model.save("/kaggle/working/saved_model_crnn_07_04_2024.h5")

# %% [markdown]
# ## Inference model

# %%
from keras.models import Model, load_model

loaded_model = load_model("/kaggle/working/saved_model_crnn_07_04_2024.h5")
loaded_model.evaluate(test_x, test_y)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7493 - loss: 0.6821
# [0.6865180730819702, 0.7678018808364868]

# %%
from keras.models import Model

# Discard the classifycation layers
matrix_size = loaded_model.layers[-4].output.shape[1]
new_model = Model(loaded_model.inputs, loaded_model.layers[-4].output)
new_model.summary()
# Out:
# Model: "functional_52"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1280, 1)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 1280, 68)  │           680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 1280, 68)  │           272 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 64, 640, 68)    │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 640, 137)   │        83,981 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 640, 137)   │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 21, 213, 137)   │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 213, 137)   │       169,058 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 21, 213, 137)   │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 5, 53, 137)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 5, 53, 137)     │       169,058 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 53, 137)     │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 1, 13, 137)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1, 13, 137)     │           548 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 13, 137)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 13, 64)         │        51,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 13, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 510,233 (1.95 MB)
#  Trainable params: 508,873 (1.94 MB)
#  Non-trainable params: 1,360 (5.31 KB)

# %%
import os
from tqdm import tqdm
import cv2

base_data_path = '/kaggle/working'
spectrogram_dir = 'spectrogram'

filenames = []
for f in os.listdir(os.path.join(base_data_path, spectrogram_dir)):
    if f.endswith(".jpg"):
        filenames.append(f)

images = []
labels = []
for f in tqdm(filenames):
    genre_variable = f.split("_")[0]
    image = cv2.imread(os.path.join(base_data_path, spectrogram_dir, f), cv2.IMREAD_UNCHANGED)
    if image.shape[:2] == (128, 1280):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = np.expand_dims(image, axis=0)
        images.append(image)
        labels.append(f.split("_")[1].split('.')[0])

images = np.concatenate(images)
embedd_images = new_model.predict(images)
labels = np.array(labels)
# Out:
# 100%|██████████| 3231/3231 [00:04<00:00, 710.10it/s]
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step

# %%
print(embedd_images.shape)
np.save("/kaggle/working/embedd_images.npy", embedd_images)
np.save("/kaggle/working/labels.npy", labels)
# Out:
# (3230, 64)

# %% [markdown]
# # NN

# %%
metadata['is_explicit'] = metadata['is_explicit'].astype('float64')

# %%
# Get min and max of numeric columns only
numeric_cols = metadata.select_dtypes(include=['number']).columns
for col in numeric_cols:
    print('col:', col, 'min:', metadata[col].min(), ', max:', metadata[col].max(),
          ', n_unique:', metadata[col].nunique())
# Out:
# col: is_explicit min: 0.0 , max: 1.0 , n_unique: 2
# col: danceability min: 0.0 , max: 0.971 , n_unique: 799
# col: energy min: 0.00086 , max: 0.997 , n_unique: 1404
# col: key min: 0.0 , max: 11.0 , n_unique: 12
# col: loudness min: -43.738 , max: 1.002 , n_unique: 2947
# col: mode min: 0.0 , max: 1.0 , n_unique: 2
# col: speechiness min: 0.0 , max: 0.491 , n_unique: 851
# col: acousticness min: 4.33e-06 , max: 0.996 , n_unique: 1429
# col: instrumentalness min: 0.0 , max: 0.986 , n_unique: 1371
# col: liveness min: 0.0222 , max: 0.979 , n_unique: 811
# col: valence min: 0.0 , max: 0.973 , n_unique: 1058
# col: tempo min: 0.0 , max: 219.169 , n_unique: 3071
# col: time_signature min: 0.0 , max: 5.0 , n_unique: 5

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# Apply Min-Max scaling to all columns
metadata_scaled = pd.DataFrame(scaler.fit_transform(metadata[numeric_cols]), columns=numeric_cols)
metadata_scaled
# Out:
#       is_explicit  danceability    energy       key  loudness  mode  \
# 0             0.0      0.781668  0.700845  0.000000  0.849195   0.0
# 1             0.0      0.682801  0.863473  0.636364  0.901654   0.0
# 2             0.0      0.590113  0.422772  0.909091  0.807264   0.0
# 3             0.0      0.890834  0.522156  0.000000  0.822664   1.0
# 4             0.0      0.751802  0.851427  0.090909  0.859566   0.0
# ...           ...           ...       ...       ...       ...   ...
# 3226          0.0      0.234809  0.005702  0.636364  0.087908   0.0
# 3227          0.0      0.500515  0.011986  0.363636  0.254448   1.0
# 3228          0.0      0.455201  0.062983  0.181818  0.295284   1.0
# 3229          0.0      0.332647  0.020620  0.363636  0.299732   0.0
# 3230          0.0      0.474768  0.252113  0.818182  0.566965   1.0
#
#       speechiness  acousticness  instrumentalness  liveness   valence  \
# 0        0.062525      0.202808          0.000133  0.439799  0.932169
# 1        0.221996      0.033932          0.000000  0.062500  0.672148
# 2        0.138086      0.553211          0.000013  0.083403  0.712230
# 3        0.075560      0.550199          0.000117  0.080163  0.768756
# 4        0.060896      0.002345          0.000026  0.302885  0.911614
# ...           ...           ...               ...       ...       ...
# 3226     0.080652      0.997992          0.877282  0.080895  0.151079
# 3227     0.101833      0.996988          0.976673  0.082358  0.082220
# 3228     0.063747      0.994980          0.961460  0.093855  0.236382
# 3229     0.078208      0.993976          0.914807  0.069921  0.072251
# 3230     0.102037      0.998996          0.920892  0.069398  0.352518
#
#          tempo  time_signature
# 0     0.424148             0.8
# 1     0.547354             0.8
# 2     0.567402             1.0
# 3     0.588856             0.8
# 4     0.535249             0.8
# ...        ...             ...
# 3226  0.335312             0.2
# 3227  0.300950             0.6
# 3228  0.327058             0.8
# 3229  0.474670             0.8
# 3230  0.447969             0.6
#
# [3231 rows x 13 columns]

# %%
# Get min and max of numeric columns only
numeric_cols = metadata_scaled.select_dtypes(include=['number']).columns
for col in numeric_cols:
    print('col:', col, 'min:', metadata_scaled[col].min(), ', max:', metadata_scaled[col].max(),
          ', n_unique:', metadata_scaled[col].nunique())
# Out:
# col: is_explicit min: 0.0 , max: 1.0 , n_unique: 2
# col: danceability min: 0.0 , max: 1.0 , n_unique: 799
# col: energy min: 0.0 , max: 0.9999999999999999 , n_unique: 1404
# col: key min: 0.0 , max: 1.0 , n_unique: 12
# col: loudness min: 0.0 , max: 1.0 , n_unique: 2947
# col: mode min: 0.0 , max: 1.0 , n_unique: 2
# col: speechiness min: 0.0 , max: 0.9999999999999999 , n_unique: 851
# col: acousticness min: 0.0 , max: 1.0 , n_unique: 1429
# col: instrumentalness min: 0.0 , max: 1.0 , n_unique: 1371
# col: liveness min: 0.0 , max: 1.0 , n_unique: 811
# col: valence min: 0.0 , max: 1.0 , n_unique: 1058
# col: tempo min: 0.0 , max: 1.0 , n_unique: 3071
# col: time_signature min: 0.0 , max: 1.0 , n_unique: 5

# %%
import numpy as np

# Genre mapping dictionary
genre_mapping = {
    "pop": 0,
    "classical": 1,
    "jazz": 2,
    "hiphop": 3,
    "electronic": 4,
    "rock": 5,
    "country": 6,
    "instrumental": 7,
}

X = metadata_scaled.values
y = metadata['genre'].values
y = np.array([genre_mapping[genre.lower()] for genre in y])
y = np.eye(len(genre_mapping))[y]
print(X.shape, y.shape)
# Out:
# (3231, 13) (3231, 8)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2584, 13) (2584, 8)
# (647, 13) (647, 8)

# %%
from tensorflow import keras

# Define the model
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(len(genre_mapping), activation='softmax')
])
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 256)            │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,256 (176.78 KB)
#  Trainable params: 45,256 (176.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss',
                               mode='min',
                               patience=5,
                               verbose=1,
                               restore_best_weights=True)

# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.25, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 34/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1234 - loss: 2.0600
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717946530.176210     188 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.1535 - loss: 2.0454 - val_accuracy: 0.2879 - val_loss: 1.9541
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3636 - loss: 1.9064 - val_accuracy: 0.3963 - val_loss: 1.7736
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4373 - loss: 1.7013 - val_accuracy: 0.4025 - val_loss: 1.5835
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4501 - loss: 1.5212 - val_accuracy: 0.4659 - val_loss: 1.4299
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4661 - loss: 1.3602 - val_accuracy: 0.4799 - val_loss: 1.3187
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5010 - loss: 1.2953 - val_accuracy: 0.4861 - val_loss: 1.2490
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4983 - loss: 1.2381 - val_accuracy: 0.4721 - val_loss: 1.2106
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5295 - loss: 1.1779 - val_accuracy: 0.5077 - val_loss: 1.1694
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5172 - loss: 1.1598 - val_accuracy: 0.5418 - val_loss: 1.1518
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5321 - loss: 1.1275 - val_accuracy: 0.5480 - val_loss: 1.1323
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5505 - loss: 1.1042 - val_accuracy: 0.5650 - val_loss: 1.1087
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5649 - loss: 1.0830 - val_accuracy: 0.5712 - val_loss: 1.1015
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5908 - loss: 1.0546 - val_accuracy: 0.5635 - val_loss: 1.0898
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5635 - loss: 1.0758 - val_accuracy: 0.5820 - val_loss: 1.0819
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5863 - loss: 1.0481 - val_accuracy: 0.5913 - val_loss: 1.0619
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6029 - loss: 1.0323 - val_accuracy: 0.5650 - val_loss: 1.0680
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5660 - loss: 1.0531 - val_accuracy: 0.5774 - val_loss: 1.0484
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6024 - loss: 1.0171 - val_accuracy: 0.5960 - val_loss: 1.0385
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6148 - loss: 1.0004 - val_accuracy: 0.5851 - val_loss: 1.0311
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6112 - loss: 0.9874 - val_accuracy: 0.5944 - val_loss: 1.0221
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5941 - loss: 0.9945 - val_accuracy: 0.5991 - val_loss: 1.0112
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6396 - loss: 0.9654 - val_accuracy: 0.5944 - val_loss: 1.0127
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6239 - loss: 0.9704 - val_accuracy: 0.5913 - val_loss: 1.0006
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6158 - loss: 0.9629 - val_accuracy: 0.5944 - val_loss: 0.9951
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5912 - loss: 0.9840 - val_accuracy: 0.5975 - val_loss: 0.9999
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6181 - loss: 0.9336 - val_accuracy: 0.6053 - val_loss: 0.9825
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6323 - loss: 0.9439 - val_accuracy: 0.6254 - val_loss: 0.9807
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6248 - loss: 0.9365 - val_accuracy: 0.6238 - val_loss: 0.9794
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6340 - loss: 0.9223 - val_accuracy: 0.6068 - val_loss: 0.9632
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6084 - loss: 0.9642 - val_accuracy: 0.6053 - val_loss: 0.9593
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6193 - loss: 0.9305 - val_accuracy: 0.6068 - val_loss: 0.9606
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6320 - loss: 0.9315 - val_accuracy: 0.6053 - val_loss: 0.9683
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6150 - loss: 0.9432 - val_accuracy: 0.5929 - val_loss: 0.9537
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6353 - loss: 0.9075 - val_accuracy: 0.5960 - val_loss: 0.9538
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6354 - loss: 0.9224 - val_accuracy: 0.6192 - val_loss: 0.9479
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6419 - loss: 0.9185 - val_accuracy: 0.6146 - val_loss: 0.9501
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6371 - loss: 0.9077 - val_accuracy: 0.6130 - val_loss: 0.9487
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6595 - loss: 0.9022 - val_accuracy: 0.6300 - val_loss: 0.9513
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6550 - loss: 0.8925 - val_accuracy: 0.6068 - val_loss: 0.9346
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6356 - loss: 0.9133 - val_accuracy: 0.6238 - val_loss: 0.9470
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6272 - loss: 0.9399 - val_accuracy: 0.6192 - val_loss: 0.9378
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6487 - loss: 0.8759 - val_accuracy: 0.6053 - val_loss: 0.9402
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6439 - loss: 0.8869 - val_accuracy: 0.6176 - val_loss: 0.9317
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6587 - loss: 0.8535 - val_accuracy: 0.6130 - val_loss: 0.9327
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6479 - loss: 0.9065 - val_accuracy: 0.6161 - val_loss: 0.9321
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6544 - loss: 0.8850 - val_accuracy: 0.6115 - val_loss: 0.9282
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6548 - loss: 0.8615 - val_accuracy: 0.6176 - val_loss: 0.9280
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6466 - loss: 0.8871 - val_accuracy: 0.6285 - val_loss: 0.9361
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6759 - loss: 0.8358 - val_accuracy: 0.6316 - val_loss: 0.9263
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6518 - loss: 0.8612 - val_accuracy: 0.6084 - val_loss: 0.9251
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6468 - loss: 0.8967 - val_accuracy: 0.6223 - val_loss: 0.9256
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6546 - loss: 0.8772 - val_accuracy: 0.6176 - val_loss: 0.9147
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6656 - loss: 0.8576 - val_accuracy: 0.6192 - val_loss: 0.9164
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6739 - loss: 0.8463 - val_accuracy: 0.6161 - val_loss: 0.9127
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6642 - loss: 0.8594 - val_accuracy: 0.6115 - val_loss: 0.9141
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6890 - loss: 0.8336 - val_accuracy: 0.6254 - val_loss: 0.9143
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6731 - loss: 0.8482 - val_accuracy: 0.6316 - val_loss: 0.9170
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6452 - loss: 0.8678 - val_accuracy: 0.6269 - val_loss: 0.9250
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6685 - loss: 0.8505 - val_accuracy: 0.6300 - val_loss: 0.9180
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 54.

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
# Out:
# (0.0, 2.0724167108535765)

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6030 - loss: 0.9585
# Test accuracy: 0.6136012077331543

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_pred, np.argmax(y_test, axis=1))
plot_confusion_matrix(cm, target_names)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          pop       0.35      0.19      0.25        73
#    classical       0.73      0.56      0.64       101
#         jazz       0.61      0.73      0.67        86
#       hiphop       0.68      0.72      0.70        72
#   electronic       0.59      0.70      0.64        98
#         rock       0.58      0.58      0.58        59
#      country       0.48      0.49      0.49        51
# instrumental       0.68      0.78      0.72       107
#
#     accuracy                           0.61       647
#    macro avg       0.59      0.59      0.59       647
# weighted avg       0.60      0.61      0.60       647

# %%
model.save("/kaggle/working/saved_model_mlp_07_04_2024.h5")

# %% [markdown]
# ## Inference model

# %%
from keras.models import Model, load_model

loaded_model = load_model("/kaggle/working/saved_model_mlp_07_04_2024.h5")
loaded_model.evaluate(X_test, y_test)

new_model = Model(loaded_model.inputs, loaded_model.layers[-2].output)
new_model.summary()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6030 - loss: 0.9585
# Model: "functional_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,736 (174.75 KB)
#  Trainable params: 44,736 (174.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
embedd_metadata = {}
tmp = new_model.predict(X)
for i in range(len(metadata)):
    embedd_metadata[metadata['track_id'][i]] = tmp[i].tolist()
# Out:
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import json
with open("embedd_metadata.json", "w") as f:
    json.dump(embedd_metadata, f)

# %%
# !rm /kaggle/working/embedd_metadata.json
